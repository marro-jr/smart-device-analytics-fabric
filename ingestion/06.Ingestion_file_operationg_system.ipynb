# %%
p_file_date = "2025-07-07"
p_environment = "Development"
# Out:
# StatementMeta(, 95b64fcd-5ce0-4780-987c-e73a93866f7f, 3, Finished, Available, Finished, False)

# %%
# %run configuration
# Out:
# StatementMeta(, 95b64fcd-5ce0-4780-987c-e73a93866f7f, 5, Finished, Available, Finished, True)
# ...

# %%
# %run commom_functions
# Out:
# StatementMeta(, 95b64fcd-5ce0-4780-987c-e73a93866f7f, 8, Finished, Available, Finished, True)

# %%
from pyspark.sql.types import StructType, StructField, IntegerType, StringType
# Out:
# StatementMeta(, 95b64fcd-5ce0-4780-987c-e73a93866f7f, 9, Finished, Available, Finished, False)

# %%
op_system_schema = StructType( fields=[
    StructField("OSID", IntegerType(), False),
    StructField("Platform", StringType(), True),
    StructField("OperatingSystem", StringType(), True),
    StructField("SoftwareExtras", StringType(), True)
])
# Out:
# StatementMeta(, 95b64fcd-5ce0-4780-987c-e73a93866f7f, 10, Finished, Available, Finished, False)

# %%
operationg_system_df = spark.read.\
schema(op_system_schema).\
option("multiLine",True).\
json(f"{bronze_folder_path}/{p_file_date}/operationg_system.json")
# Out:
# StatementMeta(, 95b64fcd-5ce0-4780-987c-e73a93866f7f, 11, Finished, Available, Finished, False)

# %%
operationg_system_dropped_df = operationg_system_df.drop("OperatingSystem", "SoftwareExtras")
# Out:
# StatementMeta(, 95b64fcd-5ce0-4780-987c-e73a93866f7f, 12, Finished, Available, Finished, False)

# %%
from pyspark.sql.functions import lit
# Out:
# StatementMeta(, 95b64fcd-5ce0-4780-987c-e73a93866f7f, 13, Finished, Available, Finished, False)

# %%
operationg_system_final = add_ingestion_date(operationg_system_dropped_df, p_file_date)\
    .withColumnRenamed("OSID", "os_id")\
    .withColumnRenamed("Platform", "platform")\
    .withColumn("envrionment", lit(p_environment))
# Out:
# StatementMeta(, 95b64fcd-5ce0-4780-987c-e73a93866f7f, 14, Finished, Available, Finished, False)

# %%
display(operationg_system_final)
# Out:
# StatementMeta(, 95b64fcd-5ce0-4780-987c-e73a93866f7f, 15, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 507fa9f5-4eb5-4342-b93a-0c6edf0e6184)

# %%
operationg_system_final.write.format("delta").mode("overwrite").option("overwriteSchema", "true").saveAsTable("operationg_system")
# Out:
# StatementMeta(, 95b64fcd-5ce0-4780-987c-e73a93866f7f, 16, Finished, Available, Finished, False)
