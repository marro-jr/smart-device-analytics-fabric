# %%
p_file_date = "2025-07-07"
p_environment = "Development"
# Out:
# StatementMeta(, 751e1e33-1de3-492f-8b3a-1273f6caca04, 3, Finished, Available, Finished, False)

# %%
# %run configuration
# Out:
# StatementMeta(, 751e1e33-1de3-492f-8b3a-1273f6caca04, 5, Finished, Available, Finished, True)
# Warning: In reference configuration run, the default lakehouse of the main notebook will be the effective default lakehouse of the session during reference run. Recommend using absolute path to read/write lakehouse in the referenced notebooks.

# %%
# %run commom_functions
# Out:
# StatementMeta(, 751e1e33-1de3-492f-8b3a-1273f6caca04, 8, Finished, Available, Finished, True)

# %%
brand_schema = "BrandID INT, Brand STRING, HardwareDesigner STRING, Manufacturer STRING"
# Out:
# StatementMeta(, 751e1e33-1de3-492f-8b3a-1273f6caca04, 9, Finished, Available, Finished, False)

# %%
brand_df = spark.read.\
schema(brand_schema).\
json(f"{bronze_folder_path}/{p_file_date}/brand.json")
# Out:
# StatementMeta(, 751e1e33-1de3-492f-8b3a-1273f6caca04, 10, Finished, Available, Finished, False)

# %%
from pyspark.sql.functions import lit
# Out:
# StatementMeta(, 751e1e33-1de3-492f-8b3a-1273f6caca04, 11, Finished, Available, Finished, False)

# %%
brand_final_df = add_ingestion_date(brand_df, p_file_date)\
    .withColumnRenamed("BrandID", "brand_id")\
    .withColumnRenamed("Brand", "brand")\
    .withColumnRenamed("HardwareDesigner", "hardware_designer")\
    .withColumnRenamed("Manufacturer", "manufacturer")\
    .withColumn("envrionment", lit(p_environment))
# Out:
# StatementMeta(, 751e1e33-1de3-492f-8b3a-1273f6caca04, 12, Finished, Available, Finished, False)

# %%
brand_final_df.write.format("delta").mode("overwrite").option("overwriteSchema", "true").saveAsTable("brand")
# Out:
# StatementMeta(, 751e1e33-1de3-492f-8b3a-1273f6caca04, 13, Finished, Available, Finished, False)

# %%
display(brand_final_df)
# Out:
# StatementMeta(, 751e1e33-1de3-492f-8b3a-1273f6caca04, 14, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, a837837c-5a27-40a6-9bb2-753291ab05d4)
