# %%
# %run configuration
# Out:
# StatementMeta(, 90b45fa8-30f3-478e-ad30-1ed821379f61, 4, Finished, Available, Finished, True)
# ...

# %%
# %run commom_functions
# Out:
# StatementMeta(, 90b45fa8-30f3-478e-ad30-1ed821379f61, 7, Finished, Available, Finished, True)

# %%
model_df = spark.sql("select * from lh_silver.dbo.model")
# Out:
# StatementMeta(, 90b45fa8-30f3-478e-ad30-1ed821379f61, 8, Finished, Available, Finished, False)

# %%
from pyspark.sql.functions import col
# Out:
# StatementMeta(, 90b45fa8-30f3-478e-ad30-1ed821379f61, 9, Finished, Available, Finished, False)

# %%
model_t_df = model_df.drop(col("envrionment"))
# Out:
# StatementMeta(, 90b45fa8-30f3-478e-ad30-1ed821379f61, 10, Finished, Available, Finished, False)

# %%
merge_condition = "tgt.model_id = src.model_id AND tgt.file_date = src.file_date"
merge_delta_lake(model_t_df, "lh_gold", "dbo", "dim_model", gold_folder_path, merge_condition, "file_date")
# Out:
# StatementMeta(, 90b45fa8-30f3-478e-ad30-1ed821379f61, 11, Finished, Available, Finished, True)

# %%
# %%sql
# select file_date, count(1) from dim_model
# GROUP BY file_date
# Out:
# StatementMeta(, 90b45fa8-30f3-478e-ad30-1ed821379f61, 12, Finished, Available, Finished, True)
# <Spark SQL result set with 1 rows and 2 fields>
