# %%
# %run configuration
# Out:
# StatementMeta(, a84d7e2f-8cb6-462a-903f-aa96f2726c86, 4, Finished, Available, Finished, True)
# Warning: In reference configuration run, the default lakehouse of the main notebook will be the effective default lakehouse of the session during reference run. Recommend using absolute path to read/write lakehouse in the referenced notebooks.

# %%
# %run commom_functions
# Out:
# StatementMeta(, a84d7e2f-8cb6-462a-903f-aa96f2726c86, 6, Finished, Available, Finished, True)

# %%
device_df = spark.sql("select * from lh_silver.dbo.device")
# Out:
# StatementMeta(, a84d7e2f-8cb6-462a-903f-aa96f2726c86, 7, Finished, Available, Finished, False)

# %%
from pyspark.sql.functions import col
# Out:
# StatementMeta(, a84d7e2f-8cb6-462a-903f-aa96f2726c86, 8, Finished, Available, Finished, False)

# %%
device_final_df = device_df.drop("envrionment", "environment")
# Out:
# StatementMeta(, a84d7e2f-8cb6-462a-903f-aa96f2726c86, 9, Finished, Available, Finished, False)

# %%
display(device_final_df)
# Out:
# StatementMeta(, a84d7e2f-8cb6-462a-903f-aa96f2726c86, 10, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 8f60cff0-02ea-44d0-ac52-2e7297e624c6)

# %%
merge_condition = 'tgt.device_id = src.device_id AND tgt.file_date = src.file_date'
merge_delta_lake(device_final_df, "lh_gold", "dbo", "fact_device", gold_folder_path, merge_condition, "file_date")
# Out:
# StatementMeta(, a84d7e2f-8cb6-462a-903f-aa96f2726c86, 11, Finished, Available, Finished, True)
